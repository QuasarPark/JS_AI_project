# %% [markdown]
# # 실습 4-1 : 결측치 및 이상치 처리

# %% [markdown]
# #### **<실습 내용>**
#
# 1. 결측치 처리
# - 결측치 확인
# - 결측치 제거
# - 결측치 대치 (값 기반, 통계 기반, 머신러닝 기반 (KNN Imputer), 시계열 보간법)
#
# 2. 이상치 탐지
# - 이상치 확인
# - IQR 기반 이상치 제거

# %% [markdown]
# ## 분석 준비

# %% [markdown]
# ### 주요 라이브러리 호출

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### 데이터 불러오기

# %%
data = pd.read_csv('dataset/day4-1_data.csv')
print("데이터 크기:", data.shape)

data.head()
# Out:
# 데이터 크기: (1567, 592)
#                   Time        0        1          2          3       4      5  \
# 0  2008-07-19 11:55:00  3030.93  2564.00  2187.7333  1411.1265  1.3602  100.0
# 1  2008-07-19 12:32:00  3095.78  2465.14  2230.4222  1463.6606  0.8294  100.0
# 2  2008-07-19 13:17:00  2932.61  2559.94  2186.4111  1698.0172  1.5102  100.0
# 3  2008-07-19 14:43:00  2988.72  2479.90  2199.0333   909.7926  1.3204  100.0
# 4  2008-07-19 15:22:00  3032.24  2502.87  2233.3667  1326.5200  1.5334  100.0
#
#           6       7       8  ...       581     582     583     584      585  \
# 0   97.6133  0.1242  1.5005  ...       NaN  0.5005  0.0118  0.0035   2.3630
# 1  102.3433  0.1247  1.4966  ...  208.2045  0.5019  0.0223  0.0055   4.4447
# 2   95.4878  0.1241  1.4436  ...   82.8602  0.4958  0.0157  0.0039   3.1745
# 3  104.2367  0.1217  1.4882  ...   73.8432  0.4990  0.0103  0.0025   2.0544
# 4  100.3967  0.1235  1.5031  ...       NaN  0.4800  0.4766  0.1045  99.3032
#
#       586     587     588       589  Pass/Fail
# 0     NaN     NaN     NaN       NaN         -1
# 1  0.0096  0.0201  0.0060  208.2045         -1
# 2  0.0584  0.0484  0.0148   82.8602          1
# 3  0.0202  0.0149  0.0044   73.8432         -1
# 4  0.0202  0.0149  0.0044   73.8432         -1
#
# [5 rows x 592 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## 1) 결측치 처리

# %% [markdown]
# > **결측치 처리** 방법으로는 대표적으로 두 가지 방식이 있음
# > 1. **제거**: 결측치가 존재하는 입력변수 또는 행을 제거
# > 2. **대치 (보간)**: 결측치를 특정 값으로 대체

# %% [markdown]
# ### 1-1) 결측치 확인

# %%
# 데이터의 각 위치가 결측치인지 확인
data.isnull()
# Out:
#        Time      0      1      2      3      4      5      6      7      8  \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False  False
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1562  False  False  False  False  False  False  False  False  False  False
# 1563  False  False  False  False  False  False  False  False  False  False
# 1564  False  False  False  False  False  False  False  False  False   True
# 1565  False  False  False  False  False  False  False  False  False  False
# 1566  False  False  False  False  False  False  False  False  False   True
#
#       ...    581    582    583    584    585    586    587    588    589  \
# 0     ...   True  False  False  False  False   True   True   True   True
# 1     ...  False  False  False  False  False  False  False  False  False
# 2     ...  False  False  False  False  False  False  False  False  False
# 3     ...  False  False  False  False  False  False  False  False  False
# 4     ...   True  False  False  False  False  False  False  False  False
# ...   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1562  ...  False  False  False  False  False  False  False  False  False
# 1563  ...   True  False  False  False  False  False  False  False  False
# 1564  ...  False  False  False  False  False  False  False  False  False
# 1565  ...  False  False  False  False  False  False  False  False  False
# 1566  ...  False  False  False  False  False  False  False  False  False
#
#       Pass/Fail
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 1562      False
# 1563      False
# 1564      False
# 1565      False
# 1566      False
#
# [1567 rows x 592 columns]

# %%
# 변수별 결측치 개수 확인
data.isnull().sum()
# Out:
# Time          0
# 0             6
# 1             7
# 2            14
# 3            14
#              ..
# 586           1
# 587           1
# 588           1
# 589           1
# Pass/Fail     0
# Length: 592, dtype: int64

# %%
# 실무에서 자주 사용하는 결측치 확인 코드

# 1. 데이터 전체 결측치 개수 / 비율 한눈에 보기
print("전체 결측치 개수:", data.isnull().sum().sum())
# Out:
# 전체 결측치 개수: 41951

# %%
# 2. 변수별 결측치 비율(%)
print(data.isnull().mean() * 100)
# Out:
# Time         0.000000
# 0            0.382897
# 1            0.446713
# 2            0.893427
# 3            0.893427
#                ...
# 586          0.063816
# 587          0.063816
# 588          0.063816
# 589          0.063816
# Pass/Fail    0.000000
# Length: 592, dtype: float64

# %%
# 3. 결측치 비율 높은 순 정렬

# .sort_values() : 값을 기준으로 정렬해주는 함수 
# ascending=False : 내림차순(큰 값 -> 작은 값)으로 정렬 (True면 오름차순)

print(data.isnull().mean().sort_values(ascending=False))
# Out:
# 293    0.911934
# 292    0.911934
# 157    0.911934
# 158    0.911934
# 492    0.855775
#          ...
# 570    0.000000
# 571    0.000000
# 572    0.000000
# 573    0.000000
# 574    0.000000
# Length: 592, dtype: float64

# %%
# 4. 결측치가 존재하는 변수만 보기
print(data.isnull().sum()[data.isnull().sum() > 0])
# Out:
# 0       6
# 1       7
# 2      14
# 3      14
# 4      14
#        ..
# 585     1
# 586     1
# 587     1
# 588     1
# 589     1
# Length: 538, dtype: int64

# %%
# 5. 결측치 여부에 따른 변수 개수 확인
print("결측치 있는 변수 수:", (data.isnull().sum() > 0).sum())
print("결측치 없는 변수 수:", (data.isnull().sum() == 0).sum())
# Out:
# 결측치 있는 변수 수: 538
# 결측치 없는 변수 수: 54

# %%
# 6. 결측치 요약 표 (DataFrame 형태)

missing_summary = pd.DataFrame({
    "결측개수": data.isnull().sum(),               # 컬럼별 결측치 개수
    "결측비율(%)": data.isnull().mean() * 100,     # 컬럼별 결측치 비율(%)
    "dtype": data.dtypes                          # 컬럼별 데이터 타입 (대치 방법 선택에 참고)
}).query("결측개수 > 0").sort_values("결측비율(%)", ascending=False)                            
   # 결측치가 1개 이상인 컬럼만 남기고 결측 비율이 높은 컬럼부터 정렬

missing_summary
# Out:
#      결측개수    결측비율(%)    dtype
# 292  1429  91.193363  float64
# 157  1429  91.193363  float64
# 158  1429  91.193363  float64
# 293  1429  91.193363  float64
# 492  1341  85.577537  float64
# ..    ...        ...      ...
# 585     1   0.063816  float64
# 586     1   0.063816  float64
# 587     1   0.063816  float64
# 588     1   0.063816  float64
# 589     1   0.063816  float64
#
# [538 rows x 3 columns]

# %% [markdown]
# ### 1-2) 결측치 제거
#
# > **결측치 제거** 방법을 선택하기 전, 행을 제거할지 변수를 제거할지 먼저 판단해야 함
# >
# > **판단 기준**
# > - 결측 있는 행의 비율이 낮고(예: 5% 미만) 데이터가 충분한 경우 → **행 제거**
# > - 특정 변수의 결측 비율이 매우 높은 경우(예: 50% 이상) → 해당 **변수(열) 제거**

# %%
# 행을 제거할지 변수를 제거할지 판단하기

# 변수 기준 결측 비율 확인 → 비율이 매우 높은 변수가 있으면 "열 제거" 고려
col_missing_ratio = data.isnull().mean().sort_values(ascending=False)

# 결측 비율이 50%를 넘는 변수 개수 확인
n_high_missing = (col_missing_ratio >= 0.5).sum()
print(f"결측 비율 50% 이상인 변수 개수: {n_high_missing}개")
# Out:
# 결측 비율 50% 이상인 변수 개수: 28개

# %%
# 행 기준 결측 비율 확인 → 결측 있는 행의 비율이 작으면 "행 제거"로도 데이터 손실이 적음
row_missing_ratio = data.isnull().any(axis=1).mean()
print(f"결측치가 하나라도 있는 행의 비율: {row_missing_ratio * 100:.2f}%")
# Out:
# 결측치가 하나라도 있는 행의 비율: 100.00%

# %%
# 결측 비율 50% 이상인 변수 이름 뽑기
cols_to_drop = col_missing_ratio[col_missing_ratio >= 0.5].index

# 해당 변수들을 제거
data2 = data.drop(columns=cols_to_drop)

print("변수 제거 전:", data.shape[1], "-> 변수 제거 후:", data2.shape[1])
# Out:
# 변수 제거 전: 592 -> 변수 제거 후: 564

# %% [markdown]
# ### 1-3) 결측치 대치

# %% [markdown]
# > **결측치 대치(Single Imputation)** 는 결측치를 하나의 값으로 보완하는 방법임
#
# | 대치 방법 | 사용 시점 |
# |---|---|
# | 0 | 결측이 "없음"을 의미하는 경우 |
# | 매우 큰 값 (99999 등) | 결측 자체를 하나의 신호로 활용하고자 하는 경우 |
# | 평균(Mean) | 연속형 변수의 대표적인 대치 방법 |
# | 중앙값(Median) | 이상치가 많은 연속형 변수 |
# | 최빈값(Mode) | 범주형 변수의 대표적인 대치 방법 |
# | Unknown | 결측 자체를 하나의 범주로 취급하고자 하는 경우 |

# %%
# 0으로 보간
data_zero = data2.fillna(0)
print("[0으로 보간] 결측치 수:", data_zero.isna().sum().sum())
# Out:
# [0으로 보간] 결측치 수: 0

# %%
# 매우 큰 값으로 보간
data_large = data2.fillna(99999)
print("[99999로 보간] 결측치 수:", data_large.isna().sum().sum())
# Out:
# [99999로 보간] 결측치 수: 0

# %%
# 변수별 평균으로 보간
data_mean = data2.fillna(data2.mean(numeric_only=True))
print("[평균 보간] 결측치 수:", data_mean.isna().sum().sum())
# Out:
# [평균 보간] 결측치 수: 0

# %%
# 변수별 중앙값으로 보간
data_median = data2.fillna(data2.median(numeric_only=True))
print("[중앙값 보간] 결측치 수:", data_median.isna().sum().sum())
# Out:
# [중앙값 보간] 결측치 수: 0

# %%
# 특정 변수 1개를 골라, 대치 방법별 값 비교
row_idx = data2.isna().any(axis=1).idxmax()

nan_cols_all = data2.columns[data2.loc[row_idx].isna()]
target_col = nan_cols_all[0]  # 비교할 변수

compare = pd.DataFrame({
    "원본 (NaN)": [data2.loc[row_idx, target_col]],
    "0 대치": [data_zero.loc[row_idx, target_col]],
    "99999 대치": [data_large.loc[row_idx, target_col]],
    "평균 대치": [data_mean.loc[row_idx, target_col]],
    "중앙값 대치": [data_median.loc[row_idx, target_col]]
}, index=[target_col])

print(f"행 {row_idx}, 변수 '{target_col}' 대치 비교:")
compare
# Out:
# 행 0, 변수 '112' 대치 비교:
#      원본 (NaN)  0 대치  99999 대치     평균 대치   중앙값 대치
# 112       NaN   0.0   99999.0  0.457538  0.46285

# %% [markdown]
# ### 1-4) KNN Imputer

# %% [markdown]
# > **KNN Imputer**는 결측치가 있는 데이터의 최근접 이웃 k개를 찾아, 해당 이웃들의 값의 평균으로 결측치를 보완함
# > - NaN이 포함된 변수를 제외한 나머지 변수로 NaN Euclidean Distance를 계산함
# > - 거리를 기반으로 유사한 데이터의 값을 가져오는 합리적인 방법임

# %%
data2_sorted = data2.sort_values('Time')  # 시간순 정렬
X = data2_sorted.drop(columns=['Time', 'Pass/Fail'])  # 센서값만 대치 대상
y = data2_sorted['Pass/Fail']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=False  # 시간 순서 유지
)

cols, idx_train, idx_test = X_train.columns, X_train.index, X_test.index  # 덮어쓰기 전에 저장

imputer = KNNImputer(n_neighbors=5)

X_train = pd.DataFrame(imputer.fit_transform(X_train), columns=cols, index=idx_train)
X_test = pd.DataFrame(imputer.transform(X_test), columns=cols, index=idx_test)

print("[Train] 결측치 수:", X_train.isnull().sum().sum())
print("[Test] 결측치 수:", X_test.isnull().sum().sum())
# Out:
# [Train] 결측치 수: 0
# [Test] 결측치 수: 0

# %% [markdown]
# ### 1-5) 시계열 보간법

# %% [markdown]
# > 시계열 데이터의 경우 시간 순서를 고려한 보간법이 효과적임
# > - **ffill (forward fill)**: 이전 시점의 값으로 채우기
# > - **bfill (backward fill)**: 다음 시점의 값으로 채우기
# > - **linear**: 위치 기반 선형 보간
# > - **time**: 시간 간격에 비례한 선형 보간 (불균등 시간 간격에 적합)

# %%
# [예제 1] 소규모 시계열 데이터로 각 보간법 결과 비교

dates = pd.date_range("2026-07-01", "2026-07-08", freq="D")
values = [10, np.nan, np.nan, 40, 50, np.nan, 60, 70]
ts = pd.Series(values, index=dates, name="값")

demo = pd.DataFrame({
    "원본": ts,
    "ffill": ts.ffill(),
    "bfill": ts.bfill(),
    "linear": ts.interpolate(method="linear"),
    "time": ts.interpolate(method="time")
})
print(demo)
print()
print("잔여 NaN 개수:",
      f"ffill: {ts.ffill().isnull().sum()},",
      f"bfill: {ts.bfill().isnull().sum()},",
      f"linear: {ts.interpolate(method='linear').isnull().sum()},",
      f"time: {ts.interpolate(method='time').isnull().sum()}")
# Out:
#               원본  ffill  bfill  linear  time
# 2026-07-01  10.0   10.0   10.0    10.0  10.0
# 2026-07-02   NaN   10.0   40.0    20.0  20.0
# 2026-07-03   NaN   10.0   40.0    30.0  30.0
# 2026-07-04  40.0   40.0   40.0    40.0  40.0
# 2026-07-05  50.0   50.0   50.0    50.0  50.0
# 2026-07-06   NaN   50.0   60.0    55.0  55.0
# 2026-07-07  60.0   60.0   60.0    60.0  60.0
# 2026-07-08  70.0   70.0   70.0    70.0  70.0
#
# 잔여 NaN 개수: ffill: 0, bfill: 0, linear: 0, time: 0

# %% [markdown]
# > **ffill+bfill**: 맨 앞 행이 결측치라 ffill만으로는 채워지지 않는 경우에 사용
# > - 먼저 ffill로 채울 수 있는 결측치를 채우고
# > - ffill로도 채워지지 않는 맨 앞 결측치는 bfill로 보간

# %%
# [예시 2] 소규모 시계열 데이터로 보간 방법별 동작 확인

dates = pd.date_range("2026-07-01", "2026-07-08", freq="D")
values = [np.nan, 10, np.nan, np.nan, 40, 50, np.nan, np.nan]
ts = pd.Series(values, index=dates, name="값")

demo = pd.DataFrame({
    "원본": ts,
    "ffill": ts.ffill(),
    "bfill": ts.bfill(),
    "linear": ts.interpolate(method="linear"),
    "time": ts.interpolate(method="time"),
    "ffill+bfill": ts.ffill().bfill(),
})
print(demo)
print()
print("잔여 NaN 개수:",
      f"ffill: {ts.ffill().isna().sum()},",
      f"bfill: {ts.bfill().isna().sum()},",
      f"linear: {ts.interpolate(method='linear').isna().sum()},",
      f"time: {ts.interpolate(method='time').isna().sum()},",
      f"ffill+bfill: {ts.ffill().bfill().isna().sum()}")
# Out:
#               원본  ffill  bfill  linear  time  ffill+bfill
# 2026-07-01   NaN    NaN   10.0     NaN   NaN         10.0
# 2026-07-02  10.0   10.0   10.0    10.0  10.0         10.0
# 2026-07-03   NaN   10.0   40.0    20.0  20.0         10.0
# 2026-07-04   NaN   10.0   40.0    30.0  30.0         10.0
# 2026-07-05  40.0   40.0   40.0    40.0  40.0         40.0
# 2026-07-06  50.0   50.0   50.0    50.0  50.0         50.0
# 2026-07-07   NaN   50.0    NaN    50.0  50.0         50.0
# 2026-07-08   NaN   50.0    NaN    50.0  50.0         50.0
#
# 잔여 NaN 개수: ffill: 1, bfill: 2, linear: 1, time: 1, ffill+bfill: 0

# %% [markdown]
# ---

# %% [markdown]
# ## 2) 이상치 처리

# %% [markdown]
# > **이상치(Outlier)** 는 데이터의 일반적인 패턴에서 크게 벗어난 값을 의미함

# %%
# 변수별 평균으로 보간한 데이터 생성
data_imputed = data2.fillna(data2.median(numeric_only=True))  # 숫자형 컬럼만 중앙값으로 결측치 대체
print(data_imputed.isna().sum().sum())  # 남은 결측치 수 확인 (0이면 결측치 없음)
# Out:
# 0

# %% [markdown]
# ### 2-1) Box Plot

# %%
plt.figure(figsize=(6, 4))
plt.boxplot(data_imputed['0'])
plt.title("Variable '0' - Box Plot")
plt.show()

# %% [markdown]
# ### 2-2) IQR 기반 이상치 제거

# %%
q1 = data_imputed['0'].quantile(0.25)  # 1사분위수 (하위 25%)
q3 = data_imputed['0'].quantile(0.75)  # 3사분위수 (상위 25%)
iqr = q3 - q1  # 사분위 범위 (IQR)

lower_bound = q1 - 1.5 * iqr  # 이상치 판단 하한선
upper_bound = q3 + 1.5 * iqr  # 이상치 판단 상한선

# 하한선~상한선 범위 안에 있는 데이터만 남김 (이상치 제거)
data_cleaned = data_imputed[(data_imputed['1'] >= lower_bound) & (data_imputed['1'] <= upper_bound)]

print("이상치 제거 전:", len(data_imputed))
print("이상치 제거 후:", len(data_cleaned))
# Out:
# 이상치 제거 전: 1567
# 이상치 제거 후: 2

# %%
data_cleaned = data_imputed.copy()  # 원본 유지하고 복사본으로 작업

numeric_cols = data_cleaned.select_dtypes(include='number').columns  # 숫자형 컬럼만 선택

for column in numeric_cols:  # 숫자형 컬럼에 대해서만 반복
    q1 = data_cleaned[column].quantile(0.25)  # 1사분위수
    q3 = data_cleaned[column].quantile(0.75)  # 3사분위수
    iqr = q3 - q1  # 사분위 범위 (IQR)

    lower_bound = q1 - 1.5 * iqr  # 이상치 판단 하한선
    upper_bound = q3 + 1.5 * iqr  # 이상치 판단 상한선

    data_cleaned = data_cleaned[(data_cleaned[column] >= lower_bound) & (data_cleaned[column] <= upper_bound)]

print("이상치 제거 전:", len(data_imputed))
print("이상치 제거 후:", len(data_cleaned))
# Out:
# 이상치 제거 전: 1567
# 이상치 제거 후: 3

# %%
# 이상치 제거 전후 Box Plot 비교
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].boxplot(data_imputed['1']); axes[0].set_title("Before")
axes[1].boxplot(data_cleaned['1']); axes[1].set_title("After")
plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 3) Vibe Coding 실습

# %% [markdown]
# **[과제 1]**
#
# 지수는 IQR 기반 이상치 제거 코드를 적용했더니 데이터가 3개만 남는 현상을 발견했습니다.
#
# 이 상태로는 실제 분석에 데이터를 전혀 쓸 수 없다고 판단하여 AI와 상의하여 왜 이런 현상이 발생하는지 원인을 파악하고 데이터를 과도하게 잃지 않으면서 이상치를 처리할 수 있는 방법을 찾아보려 합니다.
#
# AI와의 대화를 통해 원인과 대안을 정리하고 그중 하나를 실제로 적용하여 이상치 제거 전후 데이터 크기를 비교해 보세요.

# %%
data_imputed
# Out:
#                      Time        0        1          2          3       4  \
# 0     2008-07-19 11:55:00  3030.93  2564.00  2187.7333  1411.1265  1.3602
# 1     2008-07-19 12:32:00  3095.78  2465.14  2230.4222  1463.6606  0.8294
# 2     2008-07-19 13:17:00  2932.61  2559.94  2186.4111  1698.0172  1.5102
# 3     2008-07-19 14:43:00  2988.72  2479.90  2199.0333   909.7926  1.3204
# 4     2008-07-19 15:22:00  3032.24  2502.87  2233.3667  1326.5200  1.5334
# ...                   ...      ...      ...        ...        ...     ...
# 1562  2008-10-16 15:13:00  2899.41  2464.36  2179.7333  3085.3781  1.4843
# 1563  2008-10-16 20:49:00  3052.31  2522.55  2198.5667  1124.6595  0.8763
# 1564  2008-10-17 05:26:00  2978.81  2379.78  2206.3000  1110.4967  0.8236
# 1565  2008-10-17 06:01:00  2894.92  2532.01  2177.0333  1183.7287  1.5726
# 1566  2008-10-17 06:07:00  2944.92  2450.76  2195.4444  2914.1792  1.5978
#
#           5         6       7       8  ...      577     582     583     584  \
# 0     100.0   97.6133  0.1242  1.5005  ...  14.9509  0.5005  0.0118  0.0035
# 1     100.0  102.3433  0.1247  1.4966  ...  10.9003  0.5019  0.0223  0.0055
# 2     100.0   95.4878  0.1241  1.4436  ...   9.2721  0.4958  0.0157  0.0039
# 3     100.0  104.2367  0.1217  1.4882  ...   8.5831  0.4990  0.0103  0.0025
# 4     100.0  100.3967  0.1235  1.5031  ...  10.9698  0.4800  0.4766  0.1045
# ...     ...       ...     ...     ...  ...      ...     ...     ...     ...
# 1562  100.0   82.2467  0.1248  1.3424  ...  11.7256  0.4988  0.0143  0.0039
# 1563  100.0   98.4689  0.1205  1.4333  ...  17.8379  0.4975  0.0131  0.0036
# 1564  100.0   99.4122  0.1208  1.4616  ...  17.7267  0.4987  0.0153  0.0041
# 1565  100.0   98.7978  0.1213  1.4622  ...  19.2104  0.5004  0.0178  0.0038
# 1566  100.0   85.1011  0.1235  1.4616  ...  22.9183  0.4987  0.0181  0.0040
#
#           585     586     587     588       589  Pass/Fail
# 0      2.3630  0.0205  0.0148  0.0046   71.9005         -1
# 1      4.4447  0.0096  0.0201  0.0060  208.2045         -1
# 2      3.1745  0.0584  0.0484  0.0148   82.8602          1
# 3      2.0544  0.0202  0.0149  0.0044   73.8432         -1
# 4     99.3032  0.0202  0.0149  0.0044   73.8432         -1
# ...       ...     ...     ...     ...       ...        ...
# 1562   2.8669  0.0068  0.0138  0.0047  203.1720         -1
# 1563   2.6238  0.0068  0.0138  0.0047  203.1720         -1
# 1564   3.0590  0.0197  0.0086  0.0025   43.5231         -1
# 1565   3.5662  0.0262  0.0245  0.0075   93.4941         -1
# 1566   3.6275  0.0117  0.0162  0.0045  137.7844         -1
#
# [1567 rows x 564 columns]

# %% [markdown]
# ### [과제 1] 원인 분석 및 대안 정리
#
# #### 1. 왜 데이터가 3개만 남았는가?
#
# Cell 46의 IQR 이상치 제거 코드를 실행한 결과, **1,567행 → 3행**으로 급감했습니다. 주요 원인은 다음과 같습니다.
#
# | 원인 | 설명 |
# |---|---|
# | **모든 숫자형 변수에 순차 필터링** | 563개 숫자형 컬럼 각각에 대해 `하한 ≤ 값 ≤ 상한` 조건을 **연속 적용**합니다. 한 행이 단 하나의 컬럼에서라도 이상치이면 제거되므로, 조건이 누적되어 극소수 행만 남습니다. |
# | **고차원 센서 데이터** | 반도체 공정 데이터는 수백 개 센서 값을 동시에 기록합니다. 변수가 많을수록 "모든 변수가 정상 범위"인 행을 찾기 어렵습니다. |
# | **1.5×IQR 기준의 엄격함** | 제조 공정 데이터는 자연 변동이 크고 분포가 넓어, Tukey 방식(1.5×IQR)을 그대로 적용하면 정상 공정 데이터까지 이상치로 분류될 수 있습니다. |
# | **컬럼별 제거 누적 효과** | 단일 컬럼(예: `'0'`)만 적용하면 1,516행이 남지만, 113개 컬럼에서 순차 제거가 발생하며 최종 3행까지 감소합니다. |
#
# > **핵심**: 이상치 제거를 **행(row) 삭제**로, **전체 변수**에 **순차 적용**한 것이 데이터 손실의 직접적 원인입니다.
#
# #### 2. 대안 방법
#
# | 방법 | 장점 | 단점 |
# |---|---|---|
# | **① Winsorization (IQR 클리핑)** | 행 수 유지, 극단값만 상·하한으로 자름 | 정보 일부 왜곡 |
# | **② IQR 배수 완화 (예: 3.0×IQR)** | 행 삭제 방식 유지, 제거량 감소 | 여전히 다변수 순차 필터 시 손실 가능 |
# | **③ 핵심 변수만 대상으로 제한** | 해석 가능, 손실 감소 | 변수 선택 기준 필요 |
# | **④ Z-score (|z| > 3) + 행 단위 집계** | 여러 변수 중 일부만 이상인 행 보존 | 정규분포 가정 필요 |
# | **⑤ 이상치 캡핑 + 로그 변환** | 분포 왜곡 완화 후 처리 | 전처리 단계 증가 |
#
# #### 3. 선택한 대안: **Winsorization (IQR 기반 클리핑)**
#
# 행을 삭제하지 않고, 각 변수의 IQR 상·하한을 넘는 값만 **경계값으로 대체**합니다.
# 분석에 필요한 **행 수(1,567개)를 유지**하면서 극단값의 영향을 줄일 수 있어, 고차원 센서 데이터에 적합합니다.

# %%
# ===== [과제 1] 대안 적용: IQR 기반 Winsorization (클리핑) =====

import matplotlib.font_manager as fm


def setup_korean_font():
    """matplotlib/seaborn 한글 폰트 적용. sns.set_theme() 호출 후 재호출 필요."""
    try:
        _korean_fonts = ["Malgun Gothic", "NanumGothic", "AppleGothic", "Gulim"]
        _available = {f.name for f in fm.fontManager.ttflist}
        for _font in _korean_fonts:
            if _font in _available:
                plt.rcParams["font.family"] = _font
                break
        else:
            print("[경고] 한글 폰트를 찾지 못했습니다. 기본 폰트를 사용합니다.")
        plt.rcParams["axes.unicode_minus"] = False
    except Exception as e:
        print(f"[경고] 한글 폰트 설정 중 오류 발생: {e}. 기본 폰트를 사용합니다.")
        plt.rcParams["axes.unicode_minus"] = False


def remove_outliers_iqr_sequential(df, multiplier=1.5):
    """기존 방식: 모든 숫자형 컬럼에 IQR 필터를 순차 적용하여 행 제거"""
    cleaned = df.copy()
    numeric_cols = cleaned.select_dtypes(include="number").columns
    for column in numeric_cols:
        q1, q3 = cleaned[column].quantile(0.25), cleaned[column].quantile(0.75)
        iqr = q3 - q1
        if iqr == 0:
            continue
        lower, upper = q1 - multiplier * iqr, q3 + multiplier * iqr
        cleaned = cleaned[(cleaned[column] >= lower) & (cleaned[column] <= upper)]
    return cleaned


def winsorize_iqr(df, multiplier=1.5):
    """대안: 행을 삭제하지 않고 IQR 경계값으로 클리핑"""
    clipped = df.copy()
    numeric_cols = clipped.select_dtypes(include="number").columns
    clip_count = 0
    for column in numeric_cols:
        q1, q3 = clipped[column].quantile(0.25), clipped[column].quantile(0.75)
        iqr = q3 - q1
        if iqr == 0:
            continue
        lower, upper = q1 - multiplier * iqr, q3 + multiplier * iqr
        before = clipped[column].copy()
        clipped[column] = clipped[column].clip(lower=lower, upper=upper)
        clip_count += (before != clipped[column]).sum()
    return clipped, clip_count


# 비교 대상: 결측치 중앙값 대치 데이터 (Cell 41과 동일)
print("=" * 55)
print("이상치 처리 전후 데이터 크기 비교")
print("=" * 55)
print(f"처리 전 (결측치 대치 완료): {len(data_imputed):,}행 × {data_imputed.shape[1]}열")

# 1) 기존 방식: 순차 IQR 행 제거
data_iqr_removed = remove_outliers_iqr_sequential(data_imputed)
print(f"\n[기존] 순차 IQR 행 제거 후: {len(data_iqr_removed):,}행  ← 데이터 거의 소실")

# 2) 대안: Winsorization (클리핑)
data_winsorized, n_clipped = winsorize_iqr(data_imputed)
print(f"[대안] IQR Winsorization 후: {len(data_winsorized):,}행  ← 행 수 유지")
print(
    f"       클리핑된 값 개수: {n_clipped:,}개 "
    f"(전체 숫자값 대비 {n_clipped / data_imputed.select_dtypes('number').size * 100:.2f}%)"
)

# 3) 시각화 (seaborn)
TARGET_COL = "1"
METHOD_ORDER = ["처리 전", "기존 IQR 제거", "Winsorization"]
PALETTE = {"처리 전": "#4C72B0", "기존 IQR 제거": "#DD8452", "Winsorization": "#55A868"}

summary_df = pd.DataFrame({
    "처리 방법": METHOD_ORDER,
    "행 수": [len(data_imputed), len(data_iqr_removed), len(data_winsorized)],
})
summary_df["잔존 비율(%)"] = (summary_df["행 수"] / len(data_imputed) * 100).round(2)

box_df = pd.concat([
    data_imputed[[TARGET_COL]].assign(**{"처리 방법": "처리 전"}),
    data_iqr_removed[[TARGET_COL]].assign(**{"처리 방법": "기존 IQR 제거"}),
    data_winsorized[[TARGET_COL]].assign(**{"처리 방법": "Winsorization"}),
], ignore_index=True)
box_df = box_df.rename(columns={TARGET_COL: "값"})

sns.set_theme(style="whitegrid", palette="Set2", font_scale=1.05)
setup_korean_font()

fig, axes = plt.subplots(2, 1, figsize=(12, 9), gridspec_kw={"height_ratios": [1, 1.35]})

# (1) 행 수 비교 막대그래프
bar_ax = sns.barplot(
    data=summary_df,
    x="처리 방법",
    y="행 수",
    hue="처리 방법",
    order=METHOD_ORDER,
    hue_order=METHOD_ORDER,
    palette=PALETTE,
    edgecolor="white",
    linewidth=1.5,
    dodge=False,
    legend=False,
    ax=axes[0],
)
bar_ax.bar_label(bar_ax.containers[0], fmt="%,d", fontsize=11, padding=4, fontweight="bold")
for i, (_, row) in enumerate(summary_df.iterrows()):
    bar_ax.text(
        i, row["행 수"] * 0.45,
        f"잔존 {row['잔존 비율(%)']:.1f}%",
        ha="center", va="center", color="white", fontsize=10, fontweight="bold",
    )
bar_ax.set_title("이상치 처리 방법별 데이터 행 수 비교", fontsize=14, fontweight="bold", pad=12)
bar_ax.set_xlabel("")
bar_ax.set_ylabel("행 수")
sns.despine(ax=bar_ax, left=False, bottom=False)

# (2) 변수 분포 Box Plot 비교
box_ax = sns.boxplot(
    data=box_df,
    x="처리 방법",
    y="값",
    hue="처리 방법",
    order=METHOD_ORDER,
    hue_order=METHOD_ORDER,
    palette=PALETTE,
    width=0.55,
    linewidth=1.5,
    flierprops={"marker": "o", "markersize": 3, "alpha": 0.35},
    dodge=False,
    legend=False,
    ax=axes[1],
)
sns.stripplot(
    data=box_df,
    x="처리 방법",
    y="값",
    order=METHOD_ORDER,
    color="#2F2F2F",
    alpha=0.12,
    size=2,
    jitter=0.25,
    ax=box_ax,
)
box_ax.set_title(f"변수 '{TARGET_COL}' 분포 비교 (Box Plot)", fontsize=14, fontweight="bold", pad=12)
box_ax.set_xlabel("")
box_ax.set_ylabel(f"변수 '{TARGET_COL}' 값")
sns.despine(ax=box_ax, left=False, bottom=False)

fig.suptitle(
    "과제 1 — IQR 행 제거 vs Winsorization 비교",
    fontsize=16, fontweight="bold", y=1.01,
)
plt.tight_layout()
plt.show()
# Out:
# =======================================================
# 이상치 처리 전후 데이터 크기 비교
# =======================================================
# 처리 전 (결측치 대치 완료): 1,567행 × 564열
#
# [기존] 순차 IQR 행 제거 후: 3행  ← 데이터 거의 소실
# [대안] IQR Winsorization 후: 1,567행  ← 행 수 유지
#        클리핑된 값 개수: 26,649개 (전체 숫자값 대비 3.02%)
