# %% [markdown]
# # 05. 문서함 Agent
#
#
# | 주어지는 것 | 직접 만들 것 |
# |-------------|-------------|
# | `pdf_samples/*.pdf` 7개 | RAG 함수 + Tool 4개 + Agent |
# | `_catalog/index.json` + `*.summary.txt` | `get_document_catalog()` **읽기만** |

# %% [markdown]
# ---
# ## 0. 문서함 (주어진 데이터)
#
# **PDF 경로:** `samples/pdf_samples/*.pdf` 만 사용
#
# | 파일 | 유형 |
# |------|------|
# | `학칙.pdf` | 규정 |
# | `보도자료.pdf` | 보도자료 (SK하이닉스 2026 1분기 실적) |
# | `A survey on large language model based autonomous agents.pdf` | 논문 |
# | `data2vec.pdf` | 논문 |
# | `Physics-Guided Deep Learning.pdf` | 논문 |
# | `supervised-contrastive-learning-Paper.pdf` | 논문 |
# | `NeurIPS-2023-analyzing-vision-transformers-...-Paper-Conference.pdf` | 논문 |
#
# **카탈로그 :** `pdf_samples/_catalog/`
# - `index.json` — pdf_name, category, keywords, summary_file
# - `학칙.summary.txt` 등 — 문서별 한 줄 요약

# %% [markdown]
# ---
# ## 1. 전체 그림
#
# ```
# [주어짐] _catalog/          [만들 것] Tool 함수
#          index.json    →    get_document_catalog()  ← 읽기만
#          *.summary.txt
#
# [주어짐] *.pdf         →    build_pdf_index() + search_in_document()
#
#                               ↓
#                          run_agent()  ← AGENT_TOOLS + 루프
# ```

# %% [markdown]
# ---
# ## 2. Part A — RAG 기초 함수 3개 (03 노트북)

# %%
# !pip install openai python-dotenv pymupdf

import json
import re
import shutil
from pathlib import Path

import pymupdf
from dotenv import load_dotenv
from openai import OpenAI

BASE = Path('.').resolve()
load_dotenv(BASE.parent / '.env')

client = OpenAI()
DOC_LIBRARY = BASE / 'samples' / 'pdf_samples'
CATALOG_DIR = DOC_LIBRARY / '_catalog'
INDEX_CACHE = {}  # pdf_name → chunks

# %%
def split_text(text: str, chunk_size: int = 280, overlap: int = 60) -> list[str]:
    text = re.sub(r"\s+", " ", text.strip())
    if len(text) <= chunk_size:
        return [text]
    chunks, start = [], 0
    while start < len(text):
        end = start + chunk_size
        chunks.append(text[start:end])
        if end >= len(text):
            break
        start = max(0, end - overlap)
    return chunks


def tokenize(text: str) -> set[str]:
    return {t.lower() for t in re.findall(r"[가-힣a-zA-Z0-9]+", text) if len(t) > 1}


def search_chunks(query: str, chunks: list[dict], top_k: int = 3) -> list[dict]:
    q = tokenize(query)
    scored = []
    for item in chunks:
        score = len(q & tokenize(item["text"]))
        if score > 0:
            scored.append((score, item))
    scored.sort(key=lambda x: x[0], reverse=True)
    return [{**it, "score": s} for s, it in scored[:top_k]]

# %% [markdown]
# ---
# ## 3. Part B — PDF 인덱스 함수 2개

# %%
def read_pdf_text(pdf_path: Path) -> str:
    doc = pymupdf.open(pdf_path)
    return "\n".join(page.get_text() for page in doc)

def chunk_stem(pdf_name: str) -> str:
    stem = Path(pdf_name).stem
    return re.sub(r"[^\w가-힣\-]+", "_", stem)[:40].strip("_")

def build_pdf_index(pdf_name: str) -> list[dict]:
    if pdf_name in INDEX_CACHE:
        return INDEX_CACHE[pdf_name]
    pdf_path = DOC_LIBRARY / pdf_name
    if not pdf_path.exists():
        return []
    text = read_pdf_text(pdf_path)
    prefix = chunk_stem(pdf_name)
    index = [
        {
            "chunk_id": f"{prefix}_C{i:03d}",
            "source_pdf": pdf_name,
            "text": chunk,
        }
        for i, chunk in enumerate(split_text(text), 1)
    ]
    INDEX_CACHE[pdf_name] = index
    return index

# %% [markdown]
# ---
# ## 4. Part C — Tool 함수 4개 (OpenAI에 등록할 것)
#
# | 함수 | 필수 | 설명 |
# |------|------|------|
# | `list_documents()` | ✅ | pdf_samples PDF 파일명 JSON |
# | `get_document_catalog()` | ✅ | `_catalog/index.json` + summary txt **읽기** |
# | `search_in_document(pdf_name, query, top_k)` | ✅ | build_pdf_index + search_chunks → JSON |
# | `classify_pdfs_by_topic(source_folder, target_folder)` | ✅ | 주제별 하위폴더 생성 + PDF 복사 |

# %%
def list_documents() -> str:
    """pdf_samples 안 PDF 파일명 목록."""
    names = sorted(p.name for p in DOC_LIBRARY.glob("*.pdf"))
    return json.dumps({"count": len(names), "pdf_files": names}, ensure_ascii=False)

def get_document_catalog() -> str:
    """주어진 _catalog/index.json + summary txt 를 읽어 반환 (생성 X)."""
    index_path = CATALOG_DIR / "index.json"
    data = json.loads(index_path.read_text(encoding="utf-8"))
    entries = []
    for doc in data["documents"]:
        summary_path = CATALOG_DIR / doc["summary_file"]
        summary_text = summary_path.read_text(encoding="utf-8") if summary_path.exists() else ""
        one_line = ""
        for i, line in enumerate(summary_text.splitlines()):
            if "한 줄 요약" in line and i + 1 < len(summary_text.splitlines()):
                one_line = summary_text.splitlines()[i + 1].strip()
                break
        entries.append({
            "pdf_name": doc["pdf_name"],
            "category": doc.get("category", ""),
            "keywords": doc.get("keywords", []),
            "one_line_summary": one_line,
        })
    return json.dumps({"documents": entries}, ensure_ascii=False, indent=2)


def search_in_document(pdf_name: str, query: str, top_k: int = 3) -> str:
    """지정 PDF 안에서 RAG 검색."""
    hits = search_chunks(query, build_pdf_index(pdf_name), top_k=top_k)
    return json.dumps(
        {
            "pdf_name": pdf_name,
            "query": query,
            "chunks": hits,
            "message": "검색 결과 없음" if not hits else "ok",
        },
        ensure_ascii=False,
    )


def _safe_folder_name(name: str) -> str:
    cleaned = re.sub(r'[<>:"/\\|?*]', "_", name.strip())
    return cleaned[:60] or "기타"


def _load_catalog_map(source: Path) -> dict[str, dict]:
    index_path = source / "_catalog" / "index.json"
    if not index_path.exists():
        return {}
    data = json.loads(index_path.read_text(encoding="utf-8"))
    catalog_map = {}
    for doc in data.get("documents", []):
        pdf_name = doc["pdf_name"]
        summary_path = source / "_catalog" / doc.get("summary_file", "")
        one_line = ""
        if summary_path.exists():
            lines = summary_path.read_text(encoding="utf-8").splitlines()
            for i, line in enumerate(lines):
                if "한 줄 요약" in line and i + 1 < len(lines):
                    one_line = lines[i + 1].strip()
                    break
        catalog_map[pdf_name] = {
            "category": doc.get("category", ""),
            "keywords": doc.get("keywords", []),
            "one_line_summary": one_line,
        }
    return catalog_map


def _pdf_topic_hint(pdf_path: Path, catalog_entry: dict | None) -> str:
    if catalog_entry:
        return "\n".join([
            f"파일: {pdf_path.name}",
            f"카테고리: {catalog_entry.get('category', '')}",
            f"키워드: {', '.join(catalog_entry.get('keywords', []))}",
            f"한줄요약: {catalog_entry.get('one_line_summary', '')}",
        ])
    text = read_pdf_text(pdf_path)
    excerpt = re.sub(r"\s+", " ", text.strip())[:2000]
    return f"파일: {pdf_path.name}\n내용 발췌:\n{excerpt}"


def classify_pdfs_by_topic(source_folder: str, target_folder: str) -> str:
    """PDF 폴더를 주제별 하위폴더로 분류하고 원본 PDF를 복사."""
    source = Path(source_folder).resolve()
    target = Path(target_folder).resolve()

    if not source.is_dir():
        return json.dumps({"error": f"소스 폴더 없음: {source}"}, ensure_ascii=False)

    pdfs = sorted(source.glob("*.pdf"))
    if not pdfs:
        return json.dumps({"error": "PDF 파일 없음", "source": str(source)}, ensure_ascii=False)

    catalog_map = _load_catalog_map(source)
    doc_hints = [
        _pdf_topic_hint(pdf, catalog_map.get(pdf.name))
        for pdf in pdfs
    ]

    classify_prompt = f"""
아래 PDF 목록을 같은 주제끼리 묶을 폴더명을 정해줘.
- 폴더명은 짧은 한국어(2~12자)로, Windows 경로에 쓸 수 있게 특수문자 없이
- 내용·키워드·카테고리가 비슷하면 같은 topic 사용
- JSON 객체만 반환: {"assignments": [{"pdf_name": "...", "topic": "..."}, ...]}

=== 문서 목록 ===
{chr(10).join(doc_hints)}
""".strip()

    resp = client.chat.completions.create(
        model="gpt-4o-mini",
        temperature=0.1,
        messages=[{"role": "user", "content": classify_prompt}],
        response_format={"type": "json_object"},
    )
    raw = json.loads(resp.choices[0].message.content or "{}")
    assignments = raw.get("assignments") or raw.get("documents") or raw
    if isinstance(assignments, dict):
        assignments = assignments.get("items", [])
    if not isinstance(assignments, list):
        return json.dumps({"error": "분류 결과 파싱 실패", "raw": raw}, ensure_ascii=False)

    by_name = {item["pdf_name"]: item["topic"] for item in assignments if "pdf_name" in item and "topic" in item}
    target.mkdir(parents=True, exist_ok=True)

    copied = []
    for pdf in pdfs:
        topic = _safe_folder_name(by_name.get(pdf.name, "기타"))
        dest_dir = target / topic
        dest_dir.mkdir(parents=True, exist_ok=True)
        dest_path = dest_dir / pdf.name
        shutil.copy2(pdf, dest_path)
        copied.append({
            "pdf_name": pdf.name,
            "topic": topic,
            "copied_to": str(dest_path),
        })

    folders = sorted({item["topic"] for item in copied})
    return json.dumps(
        {
            "source_folder": str(source),
            "target_folder": str(target),
            "folder_count": len(folders),
            "folders": folders,
            "copied_count": len(copied),
            "files": copied,
        },
        ensure_ascii=False,
        indent=2,
    )

# %% [markdown]
# ---
# ## 5. Part D — Agent 합치기
#
# 1. `AGENT_TOOLS` — 위 3개 함수 스키마
# 2. `TOOL_FUNCTIONS` — 이름 → 함수 dict
# 3. `AGENT_SYSTEM` — catalog 먼저, 그다음 search
# 4. `run_agent(question)` — **tool_calls 없을 때까지 루프**

# %%
AGENT_TOOLS = [
    {
        "type": "function",
        "function": {
            "name": "list_documents",
            "description": "pdf_samples 폴더의 PDF 파일명 목록.",
            "parameters": {"type": "object", "properties": {}},
        },
    },
    {
        "type": "function",
        "function": {
            "name": "get_document_catalog",
            "description": "문서함 카탈로그(유형·한줄요약·키워드). 어떤 PDF를 열지 정할 때 먼저 호출.",
            "parameters": {"type": "object", "properties": {}},
        },
    },
    {
        "type": "function",
        "function": {
            "name": "search_in_document",
            "description": "카탈로그로 pdf_name을 고른 뒤, 해당 PDF 내에서 질문과 유사한 조항 검색.",
            "parameters": {
                "type": "object",
                "properties": {
                    "pdf_name": {"type": "string"},
                    "query": {"type": "string"},
                    "top_k": {"type": "integer"},
                },
                "required": ["pdf_name", "query"],
            },
        },
    },
    {
        "type": "function",
        "function": {
            "name": "classify_pdfs_by_topic",
            "description": "PDF 폴더를 주제별 하위폴더로 분류. 타겟 폴더에 하위폴더를 만들고 원본 PDF를 복사.",
            "parameters": {
                "type": "object",
                "properties": {
                    "source_folder": {
                        "type": "string",
                        "description": "PDF가 있는 소스 폴더 경로",
                    },
                    "target_folder": {
                        "type": "string",
                        "description": "주제별 하위폴더를 만들 타겟 폴더 경로",
                    },
                },
                "required": ["source_folder", "target_folder"],
            },
        },
    },
]

TOOL_FUNCTIONS = {
    "list_documents": lambda **_: list_documents(),
    "get_document_catalog": lambda **_: get_document_catalog(),
    "search_in_document": search_in_document,
    "classify_pdfs_by_topic": classify_pdfs_by_topic,
}

AGENT_SYSTEM = """
너는 pdf_samples 문서함 Q&A 도우미입니다.

순서:
1. get_document_catalog 로 문서 목록·한줄요약 확인
2. 질문에 맞는 pdf_name 고른 뒤 search_in_document 호출
3. 도구 결과에 없으면 추측하지 말 것

답변: 한국어 bullet 3개 이내, 마지막 bullet 근거: [pdf_name] chunk_id
""".strip()

# %%
def run_agent(question: str, max_rounds: int = 8) -> str:
    """tool_calls 가 없을 때까지 반복."""
    messages = [
        {"role": "system", "content": AGENT_SYSTEM},
        {"role": "user", "content": question},
    ]
    for _ in range(max_rounds):
        resp = client.chat.completions.create(
            model="gpt-5.4-nano",
            temperature=0.1,
            messages=messages,
            tools=AGENT_TOOLS,
        )
        msg = resp.choices[0].message
        if not msg.tool_calls:
            return msg.content or ""
        messages.append(msg)
        for tc in msg.tool_calls:
            fn = tc.function.name
            args = json.loads(tc.function.arguments or "{}")
            result = TOOL_FUNCTIONS[fn](**args)
            messages.append({
                "role": "tool",
                "tool_call_id": tc.id,
                "content": result,
            })
    return "tool 호출 최대 횟수 초과"

# %% [markdown]
# ---
# ## 6. 데모 — 6개 통과
#
# | # | 질문 | 기대 PDF |
# |---|------|----------|
# | 1 | 문서함에 어떤 PDF가 있어? | catalog |
# | 2 | 석사학위과정 수업연한은? | `학칙.pdf` |
# | 3 | LLM autonomous agent 서베이 주제는? | survey 논문 |
# | 4 | data2vec modality 세 가지는? | `data2vec.pdf` |
# | 5 | 2026년 1분기 SK하이닉스 영업이익은? | `보도자료.pdf` |
# | 6 | ViT class embedding 논문 한 줄로 | NeurIPS ViT 논문 |

# %%
DEMO = [
    '문서함에 어떤 PDF가 있어?',
    '석사학위과정 수업연한은?',
    'LLM autonomous agent 서베이 논문의 주제는?',
    'data2vec가 다루는 modality 세 가지는?',
    '2026년 1분기 SK하이닉스 영업이익은?',
    'Vision Transformer class embedding 논문이 뭐 다루는지 한 줄로',
]

for q in DEMO:
    print('=' * 60, '\nQ:', q, '\n', run_agent(q))
# Out:
# ============================================================
# Q: 문서함에 어떤 PDF가 있어?
#  - **학칙.pdf**: 연세대학교 대학원 학칙 전문(학위과정, 수업·재학연한, 입학·휴학·논문·학점 등)
# - **보도자료.pdf**: SK하이닉스 2026년 1분기 경영실적 보도자료(매출·영업이익·순이익, AI/HBM, D램·낸드 전망)
# - **논문들**: *A survey on large language model based autonomous agents.pdf*, *data2vec.pdf*, *Physics-Guided Deep Learning.pdf*, *supervised-contrastive-learning-Paper.pdf*, *NeurIPS-2023-analyzing-vision-transformers-for-image-classification-in-class-embedding-space-Paper-Conference.pdf*
# ============================================================
# Q: 석사학위과정 수업연한은?
#  - 석사학위과정 수업연한은 **2년(4학기)** 입니다.
# - (참고) 학위수여 자격 요건을 충족한 경우 **수업연한을 1학기 단축**할 수 있습니다.
# - 근거: **[학칙.pdf] 학칙_C004**
# ============================================================
# Q: LLM autonomous agent 서베이 논문의 주제는?
#  - 해당 PDF(“A survey on large language model based autonomous agents.pdf”)에서 **“서베이 논문의 주제”**를 직접 확인할 수 있는 검색 결과가 없습니다.
# - 따라서 문서 근거 없이 주제를 추측해 답변할 수 없습니다.
# - 근거: [A survey on large language model based autonomous agents.pdf] chunk_id 없음
# ============================================================
# Q: data2vec가 다루는 modality 세 가지는?
#  - data2vec이 다루는 modality 3가지는 **speech(음성)**, **vision(비전/이미지)**, **language(언어)** 입니다.
# - 근거: data2vec 논문 제목/초록에 “**Self-supervised Learning in Speech, Vision and Language**”로 명시되어 있습니다.
# - 근거: [data2vec.pdf] data2vec_C001
# ============================================================
# Q: 2026년 1분기 SK하이닉스 영업이익은?
#  - 2026년 1분기 SK하이닉스 **영업이익은 37조 6,103억 원**입니다.
# - 근거: [보도자료.pdf] chunk_id: 보도자료_C001
# ============================================================
# Q: Vision Transformer class embedding 논문이 뭐 다루는지 한 줄로
#  - ViT의 내부 표현을 **학습된 class embedding space**에 투영해, 이미지 분류에서 범주(클래스) 표현이 어떻게 형성되는지 분석합니다.
# - 또한 분류를 위해 학습된 ViT를 **class embedding space 관점에서 역추적(분석/해석)**하는 방법을 제안합니다.
# - 근거: [NeurIPS-2023-analyzing-vision-transformers-for-image-classification-in-class-embedding-space-Paper-Conference.pdf] NeurIPS-2023-analyzing-vision-transforme_C003

# %% [markdown]
# ---
# ## 7. PDF 주제별 분류
#
# `classify_pdfs_by_topic` — 소스 폴더의 PDF를 LLM으로 주제별 분류하고, 타겟 폴더에 하위폴더를 만든 뒤 **원본 PDF를 복사**합니다.

# %%
SOURCE_PDF_DIR = DOC_LIBRARY
TARGET_CLASSIFIED_DIR = BASE / 'samples' / 'pdf_samples' / '_classified'

result = classify_pdfs_by_topic(str(SOURCE_PDF_DIR), str(TARGET_CLASSIFIED_DIR))
print(result)
# Out:
# {
#   "source_folder": "D:\\autornd\\SK Autonomous R&D\\실습\\4일차\\samples\\pdf_samples",
#   "target_folder": "D:\\autornd\\SK Autonomous R&D\\실습\\4일차\\samples\\pdf_samples\\_classified",
#   "folder_count": 1,
#   "folders": [
#     "기타"
#   ],
#   "copied_count": 7,
#   "files": [
#     {
#       "pdf_name": "A survey on large language model based autonomous agents.pdf",
#       "topic": "기타",
#       "copied_to": "D:\\autornd\\SK Autonomous R&D\\실습\\4일차\\samples\\pdf_samples\\_classified\\기타\\A survey on large language model based autonomous agents.pdf"
#     },
#     {
#       "pdf_name": "data2vec.pdf",
#       "topic": "기타",
#       "copied_to": "D:\\autornd\\SK Autonomous R&D\\실습\\4일차\\samples\\pdf_samples\\_classified\\기타\\data2vec.pdf"
#     },
#     {
#       "pdf_name": "NeurIPS-2023-analyzing-vision-transformers-for-image-classification-in-class-embedding-space-Paper-Conference.pdf",
#       "topic": "기타",
#       "copied_to": "D:\\autornd\\SK Autonomous R&D\\실습\\4일차\\samples\\pdf_samples\\_classified\\기타\\NeurIPS-2023-analyzing-vision-transformers-for-image-classification-in-class-embedding-space-Paper-Conference.pdf"
#     },
#     {
#       "pdf_name": "Physics-Guided Deep Learning.pdf",
#       "topic": "기타",
#       "copied_to": "D:\\autornd\\SK Autonomous R&D\\실습\\4일차\\samples\\pdf_samples\\_classified\\기타\\Physics-Guided Deep Learning.pdf"
#     },
#     {
#       "pdf_name": "supervised-contrastive-learning-Paper.pdf",
#       "topic": "기타",
#       "copied_to": "D:\\autornd\\SK Autonomous R&D\\실습\\4일차\\samples\\pdf_samples\\_classified\\기타\\supervised-contrastive-learning-Paper.pdf"
#     },
#     {
#       "pdf_name": "보도자료.pdf",
#       "topic": "기타",
#       "copied_to": "D:\\autornd\\SK Autonomous R&D\\실습\\4일차\\samples\\pdf_samples\\_classified\\기타\\보도자료.pdf"
#     },
#     {
#       "pdf_name": "학칙.pdf",
#       "topic": "기타",
#       "copied_to": "D:\\autornd\\SK Autonomous R&D\\실습\\4일차\\samples\\pdf_samples\\_classified\\기타\\학칙.pdf"
#     }
#   ]
# }
